# %% [markdown]
# # __Classifiers effectivness__
#
#
# __Task__: For any data set form UCI or Kaggle create following classifiers:
#
# - NaiveBayes
# - Logistic Regression
# - SVM
# - 1NN
# - KNN
#
# and calculate  basic metrics:
# - Accuracy
# - F1
# - Precision
# - Recall
# - Specificity
# - AUC
#
# Results present on charts and table.
#
# Repeat above for the following evalution methods:
# - redistribution (training and testing on same dataset)
# - split 70/30
# - crossvalidation
# - leave-one-out
#
#
#
# __Source of data:__  https://archive.ics.uci.edu/ml/index.php
#
# __Dataset:__  DataWineSet
#
# _Remarks:_
#
# _Charts can be moved by 2% in order to avoid overlapping_
#
# _Confusion Matris for crossvalidation and leaveoneout calculated as sum of iterations of test and training  set_
#
# _Metrics in macro version_
#
# _Metrics for crossvalidation calculated as mean of metrics of  iterations over test training set_
#
# _Metrics for leaveOneout calculated from sum up results of the iterations over test and training set_

# %% [markdown]
# ## Dataset basic information

# %%
from sklearn import datasets
wine = datasets.load_wine()
X = wine.data
y = wine.target
print(wine.DESCR)
# Out:
# .. _wine_dataset:
#
# Wine recognition dataset
# ------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 178 (50 in each of three classes)
#     :Number of Attributes: 13 numeric, predictive attributes and the class
#     :Attribute Information:
#  		- Alcohol
#  		- Malic acid
#  		- Ash
# 		- Alcalinity of ash
#  		- Magnesium
# 		- Total phenols
#  		- Flavanoids
#  		- Nonflavanoid phenols
#  		- Proanthocyanins
# 		- Color intensity
#  		- Hue
#  		- OD280/OD315 of diluted wines
#  		- Proline
#
#     - class:
#             - class_0
#             - class_1
#             - class_2
#
#     :Summary Statistics:
#
#     ============================= ==== ===== ======= =====
#                                    Min   Max   Mean     SD
#     ============================= ==== ===== ======= =====
#     Alcohol:                      11.0  14.8    13.0   0.8
#     Malic Acid:                   0.74  5.80    2.34  1.12
# ...

# %% [markdown]
# ## Evaluation method: redistribution

# %%
from klasyfikacja import zad2_redyst

zad2_redyst(X, y)

# %% [markdown]
# ## Evaluation method: split 70%/30%

# %%
from klasyfikacja import zad2_podzial

zad2_podzial(X, y)

# %% [markdown]
# ## Evaluation method: crossvalidation  (k=5)

# %%
from klasyfikacja import zad2_kross

zad2_kross(X, y)

# %% [markdown]
# ## Evaluation method:  LeaveOneOut

# %%
from klasyfikacja import zad2_loo

zad2_loo(X, y)

# %%
import sys
del sys.modules["klasyfikacja"]
