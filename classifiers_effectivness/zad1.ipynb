# %% [markdown]
# ## __Quality of knn algorithm__

# %% [markdown]
# __Task:__  Create chart presenting realation between accuaracy and other metrics and numbers of nieghbours for knn algorithm
#
#
#
# _Dataset:_
# | feature 1 | feature 2 | class |
# |---|---|---|
# | 1 | 5.3 | 2 |
# | 2.8 | 7.6 | 1 |
# | 4.2 | 9.3 | 2 |
# | 1.5 | 3.1 | 1 |
# | 9.8 | 7.5 | 2 |
# | 6.1 | 0.5 | 2 |
# | 4.7 | 8.9 | 2 |
# | 1.2 | 8 | 1 |
# | 8.2 | 3.3 | 1 |
# | 6.4 | 5.5 | 1 |
#
#
#
#
#
# __Dataset__: 2 features, 2 classes, 10 observations
#
# __Classifier__  : knn
#
# __Numbers of neighbours__ : 1 to 9
#
# __Evaluation method__ : redistribution
#
#
# _Attention: charts can be slightly moved versus its original positions in order to avoid ovelapping_

# %%
from klasyfikacja import zad1
zad1()

# %%
import sys
del sys.modules["klasyfikacja"]
